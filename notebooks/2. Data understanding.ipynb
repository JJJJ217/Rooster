# %% [markdown]
# # 2. Data Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets from the Excel workbook
customers = pd.read_excel(
    '../datafiles/rooster_cleaned.xlsx',
    sheet_name='customers_cleaned'
)

orders = pd.read_excel(
    '../datafiles/rooster_cleaned.xlsx',
    sheet_name='orders_cleaned'
)

orderlines = pd.read_excel(
    '../datafiles/rooster_cleaned.xlsx',
    sheet_name='orderlines_cleaned'
)

products = pd.read_excel(
    '../datafiles/rooster_cleaned.xlsx',
    sheet_name='products_cleaned'
)
