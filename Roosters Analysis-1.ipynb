# %% [markdown]
# # Roosters

# %%
import os

print(os.getcwd())
# Out:
# /Users/jiaming/Business/Business Analytic/Business Analytic Cap/assignment 1/Rooster

# %%
import pandas as pd

# %%
df_raw = pd.read_excel('rooster_a2_retention2.xlsx')
df = df_raw

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6606 entries, 0 to 6605
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customer_email                   6606 non-null   object
#  1   customer_first_order_date        6606 non-null   datetime64[ns]
#  2   customer_last_order_date         6606 non-null   datetime64[ns]
#  3   customer_total_orders            6606 non-null   int64
#  4   customer_total_spent             6606 non-null   float64
#  5   coupon_count                     6606 non-null   int64
#  6   first_order_coupon_code          3019 non-null   object
#  7   first_order_used_coupon          6606 non-null   int64
#  8   first_order_acquisition_channel  6606 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(3)
# memory usage: 464.6+ KB

# %%
df.head()
# Out:
#                      customer_email customer_first_order_date  \
# 0  eml_0002a23b87@gmail.example.net                2024-08-07
# 1  eml_00078d07d7@gmail.example.net                2024-10-13
# 2  eml_000e7aef6e@gmail.example.net                2025-03-15
# 3  eml_00163a8915@gmail.example.net                2024-10-06
# 4  eml_0017ce14ce@gmail.example.net                2024-05-24
#
#   customer_last_order_date  customer_total_orders  customer_total_spent  \
# 0               2024-08-07                      1                103.89
# 1               2024-10-13                      1                 44.45
# 2               2025-04-14                      2                135.00
# 3               2024-10-20                      2                 78.00
# 4               2024-12-17                      5                332.60
#
#    coupon_count first_order_coupon_code  first_order_used_coupon  \
# 0             1                ROOSTER5                        1
# ...
